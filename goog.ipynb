# %%
# try:
#     import os
#     from google.colab.drive import mount
#     mount('./drive')
#     %cd 'drive/My Drive/Colab Notebooks/Final Project'
#     if not os.path.exists('flower_data.zip'):
# #     !wget https://s3.amazonaws.com/content.udacity-data.com/courses/nd188/flower_data.zip
#         !wget https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz
#     if not os.path.exists('flower_data'):
# #     !unzip flower_data.zip
#         !mkdir flower_data
#         !tar -C ./flower_data -xvzf flower_data.tar.gz
# except ImportError:
#     pass
# !nvidia-smi
# Out:
# Wed Jan  9 10:19:53 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 396.44                 Driver Version: 396.44                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           On   | 000067B0:00:00.0 Off |                    0 |
# | N/A   38C    P8    32W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip3 uninstall -y Pillow
# !pip3 install Pillow==5.3.0
# !pip3 install http://download.pytorch.org/whl/cu80/torch-0.4.1-cp36-cp36m-linux_x86_64.whl
# # !pip3 install https://download.pytorch.org/whl/cu80/torch-0.4.0-cp36-cp36m-linux_x86_64.whl
# !pip3 install torchvision
import PIL
print(PIL.PILLOW_VERSION)
# Out:
# 5.3.0

# %%
# Imports here
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader, random_split
from torchvision.datasets import ImageFolder
from torch import optim, nn
from torch.optim import lr_scheduler
import time
import os
import copy
import json
import time

# %%
# !pip install gdown==3.6.0
# # https://drive.google.com/open?id=1W26FgrVjl-HHG77XL--v4s1mgE0a0ju1
# my_file_id = '1W26FgrVjl-HHG77XL--v4s1mgE0a0ju1'
# !gdown https://drive.google.com/uc?id={my_file_id}
# !ls
# !unzip big_data.zip
from IPython.display import Audio, display

def allDone():
    display(Audio(url='https://sound.peal.io/ps/audios/000/000/537/original/woo_vu_luvub_dub_dub.wav', autoplay=True))

# %%
data_dir = 'big_data'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# TODO: Define your transforms for the training and validation sets
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]
batch_size = 32
data_transforms = {
    "train": transforms.Compose([
        transforms.RandomAffine(45, translate=(0.1,0.1), scale=(0.8,1.2), shear=10),
        transforms.RandomHorizontalFlip(), transforms.RandomVerticalFlip(),
        transforms.RandomResizedCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ]),
    "valid": transforms.Compose([
        transforms.Resize((224,224)),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ]),
    "test": transforms.Compose([
        transforms.Resize((224,224)),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ])
}

# TODO: Load the datasets with ImageFolder
image_datasets = {
    "train": ImageFolder(train_dir, transform=data_transforms["train"]),
    "valid": ImageFolder(valid_dir, transform=data_transforms["valid"]),
    "test": ImageFolder(valid_dir, transform=data_transforms["test"])
}

# ratio = 0.25
# num = int(ratio*len(image_datasets["train"]))
# scale_down,_ = random_split(image_datasets["train"], [num, len(image_datasets["train"])-num])
# TODO: Using the image datasets and the trainforms, define the dataloaders

dataloaders = {
    "train": DataLoader(image_datasets["train"], batch_size=batch_size, shuffle=True),
    "valid": DataLoader(image_datasets["valid"], batch_size=batch_size, shuffle=True),
    "test": DataLoader(image_datasets["test"], batch_size=batch_size, shuffle=True),
}

# dataloaders = {
#     "train": DataLoader(scale_down, batch_size=batch_size, shuffle=True),
#     "valid": DataLoader(image_datasets["valid"], batch_size=batch_size, shuffle=True),
#     "test": DataLoader(image_datasets["test"], batch_size=batch_size, shuffle=True),
# }

# %%
# with open('cat_to_name.json', 'r') as f:
#     cat_to_name = json.load(f)
# sorted(cat_to_name)
cat_to_name = [0]*102

# %%
def plt_stats(stats_error, stats_accuracy):
    plt.figure(figsize=(15,5))
    plt.title('stats')
    plt.subplot(121)
    plt.plot(stats_error['train'],label="train")
    plt.plot(stats_error['valid'], label="validation")
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend()
    plt.title("LOSS")
    plt.subplot(122)
    plt.plot(stats_accuracy['train'], label="train")
    plt.plot(stats_accuracy['valid'], label="validation")
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.legend()
    plt.title("ACCURACY")
    plt.savefig(str(time.time())+'.jpg')

# %%
def train(epochs, model, optimizer, scheduler, dataloaders, criterion, model_name="my_model.pt", save=True, best_acc=0.0, stats_error = {'train':[], 'valid': []}, stats_accuracy = {'train':[], 'valid': []}):
    since = time.time()
    best_model_wts = copy.deepcopy(model.state_dict())
    for epoch in range(epochs):
        print('Epoch {}/{}'.format(epoch+1, epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            print(phase, end='')
            if phase == 'train':
                if str(type(scheduler)) != "<class 'torch.optim.lr_scheduler.ReduceLROnPlateau'>":
                    scheduler.step()
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0.0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                print('.', end='')
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data).item()
            print()
            
            
            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects / len(dataloaders[phase].dataset)
            stats_error[phase].append(epoch_loss)
            stats_accuracy[phase].append(epoch_acc)
            
            if phase=="valid" and str(type(scheduler)) == "<class 'torch.optim.lr_scheduler.ReduceLROnPlateau'>":
                scheduler.step(metrics = epoch_loss)
            
            
            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

        # deep copy the model
            if phase == 'valid' and epoch_acc >= best_acc:
                print("accuracy increased from {:.4f} to {:.4f}, saving model....".format(best_acc, epoch_acc))
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
                if save:
                    torch.save(model.state_dict(), model_name)
        print()
    
    json.dump({"stats_error":stats_error, "stats_accuracy": stats_accuracy}, open('stats-'+str(time.time())+'.json', 'w'))
    plt_stats(stats_error, stats_accuracy)
    model.load_state_dict(best_model_wts)
    
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    
    allDone()
    
    return best_acc, model

# %%
def test(model, dataloaders):
    model.eval()
    running_corrects = 0.0
    for batch, (inputs, labels) in enumerate(dataloaders['test']):
        inputs = inputs.to(device)
        labels = labels.to(device)
        with torch.set_grad_enabled(False):
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
        # statistics
        accu =  torch.sum(preds == labels.data)
        running_corrects += accu.data.item()
        print("batch:", batch+1, "Accuracy:", accu.data.item()/len(inputs))
    print("overall accuracy:", running_corrects/len(dataloaders['test'].dataset))

# %%
def google_test(model):
    # !git clone https://github.com/GabrielePicco/deep-learning-flower-identifier
    # !pip install airtable
    import sys
    sys.path.insert(0, 'deep-learning-flower-identifier')
    
    import PIL
    print(PIL.PILLOW_VERSION)

    # model = model.to(device)
    model.eval()
    from test_model_pytorch_facebook_challenge import calc_accuracy
    calc_accuracy(model, input_image_size=224, use_google_testset=True, batch_size=batch_size, norm_mean = mean, norm_std=std)

# %%
# TODO: Build and train your network
model = torchvision.models.resnet152(pretrained=True)

length = len(list(model.parameters()))

for idx,param in enumerate(model.parameters()):
    if idx < length-10:
        param.requires_grad = False

in_features = model.fc.in_features
# in_features = model.classifier[0].in_features
out_features = len(cat_to_name)

fc = nn.Linear(in_features, out_features)

model.fc = fc

model = model.to(device)

# %%
epochs = 20
lr = 1e-1
gamma = 0.1
step_size = 5
momentum = 0.8
cooldown = 1


optimizer = optim.SGD(model.parameters(), lr=lr, momentum = momentum)
criterion = nn.CrossEntropyLoss()
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, patience=step_size, cooldown=cooldown,verbose=True)

# %%
best_acc, model = train(epochs, model, optimizer, scheduler, dataloaders, criterion, model_name="goog_prev.pt")
# Out:
# Epoch 1/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 2.3129 Acc: 0.5442
# valid.......................................................
# valid Loss: 0.8601 Acc: 0.7872
# accuracy increased from 0.0000 to 0.7872, saving model....
#
# Epoch 2/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.8948 Acc: 0.7730
# valid.......................................................
# valid Loss: 0.4584 Acc: 0.8693
# accuracy increased from 0.7872 to 0.8693, saving model....
#
# Epoch 3/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.7104 Acc: 0.8088
# valid.......................................................
# valid Loss: 0.3673 Acc: 0.8959
# accuracy increased from 0.8693 to 0.8959, saving model....
#
# Epoch 4/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.5539 Acc: 0.8500
# valid.......................................................
# valid Loss: 0.2093 Acc: 0.9381
# accuracy increased from 0.8959 to 0.9381, saving model....
#
# Epoch 5/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.4990 Acc: 0.8611
# valid.......................................................
# valid Loss: 0.2245 Acc: 0.9398
# accuracy increased from 0.9381 to 0.9398, saving model....
#
# Epoch 6/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.4466 Acc: 0.8750
# valid.......................................................
# valid Loss: 0.2033 Acc: 0.9422
# accuracy increased from 0.9398 to 0.9422, saving model....
#
# Epoch 7/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.4052 Acc: 0.8885
# valid.......................................................
# valid Loss: 0.2004 Acc: 0.9439
# accuracy increased from 0.9422 to 0.9439, saving model....
#
# Epoch 8/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.3870 Acc: 0.8917
# valid.......................................................
# valid Loss: 0.1455 Acc: 0.9566
# accuracy increased from 0.9439 to 0.9566, saving model....
#
# Epoch 9/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.3722 Acc: 0.8986
# valid.......................................................
# valid Loss: 0.1543 Acc: 0.9560
#
# Epoch 10/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.3579 Acc: 0.8973
# valid.......................................................
# valid Loss: 0.1211 Acc: 0.9607
# accuracy increased from 0.9566 to 0.9607, saving model....
#
# Epoch 11/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.3334 Acc: 0.9060
# valid.......................................................
# valid Loss: 0.1251 Acc: 0.9676
# accuracy increased from 0.9607 to 0.9676, saving model....
#
# Epoch 12/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.3299 Acc: 0.9085
# valid.......................................................
# valid Loss: 0.1430 Acc: 0.9589
#
# Epoch 13/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.3084 Acc: 0.9138
# valid.......................................................
# valid Loss: 0.1063 Acc: 0.9682
# accuracy increased from 0.9676 to 0.9682, saving model....
#
# Epoch 14/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.2909 Acc: 0.9183
# valid.......................................................
# valid Loss: 0.0919 Acc: 0.9711
# accuracy increased from 0.9682 to 0.9711, saving model....
#
# Epoch 15/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.2811 Acc: 0.9217
# valid.......................................................
# valid Loss: 0.0835 Acc: 0.9728
# accuracy increased from 0.9711 to 0.9728, saving model....
#
# Epoch 16/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.2710 Acc: 0.9215
# valid.......................................................
# valid Loss: 0.0726 Acc: 0.9786
# accuracy increased from 0.9728 to 0.9786, saving model....
#
# Epoch 17/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.2737 Acc: 0.9241
# valid.......................................................
# valid Loss: 0.1181 Acc: 0.9670
#
# Epoch 18/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.2639 Acc: 0.9279
# valid.......................................................
# valid Loss: 0.0878 Acc: 0.9728
#
# Epoch 19/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.2435 Acc: 0.9323
# valid.......................................................
# valid Loss: 0.0646 Acc: 0.9826
# accuracy increased from 0.9786 to 0.9826, saving model....
#
# Epoch 20/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.2256 Acc: 0.9372
# valid.......................................................
# valid Loss: 0.0763 Acc: 0.9792
#
# Training complete in 125m 29s
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="https://sound.peal.io/ps/audios/000/000/537/original/woo_vu_luvub_dub_dub.wav" type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
test(model, dataloaders)
# Out:
# batch: 1 Accuracy: 1.0
# batch: 2 Accuracy: 1.0
# batch: 3 Accuracy: 1.0
# batch: 4 Accuracy: 0.96875
# batch: 5 Accuracy: 1.0
# batch: 6 Accuracy: 1.0
# batch: 7 Accuracy: 0.96875
# batch: 8 Accuracy: 1.0
# batch: 9 Accuracy: 1.0
# batch: 10 Accuracy: 1.0
# batch: 11 Accuracy: 0.96875
# batch: 12 Accuracy: 0.96875
# batch: 13 Accuracy: 1.0
# batch: 14 Accuracy: 0.90625
# batch: 15 Accuracy: 1.0
# batch: 16 Accuracy: 1.0
# batch: 17 Accuracy: 1.0
# batch: 18 Accuracy: 1.0
# batch: 19 Accuracy: 0.9375
# batch: 20 Accuracy: 1.0
# batch: 21 Accuracy: 0.96875
# batch: 22 Accuracy: 1.0
# batch: 23 Accuracy: 0.96875
# batch: 24 Accuracy: 0.96875
# batch: 25 Accuracy: 0.96875
# batch: 26 Accuracy: 1.0
# batch: 27 Accuracy: 1.0
# batch: 28 Accuracy: 1.0
# batch: 29 Accuracy: 0.96875
# batch: 30 Accuracy: 0.96875
# batch: 31 Accuracy: 1.0
# batch: 32 Accuracy: 1.0
# batch: 33 Accuracy: 0.9375
# batch: 34 Accuracy: 0.96875
# batch: 35 Accuracy: 1.0
# batch: 36 Accuracy: 1.0
# batch: 37 Accuracy: 1.0
# batch: 38 Accuracy: 1.0
# batch: 39 Accuracy: 1.0
# batch: 40 Accuracy: 0.96875
# batch: 41 Accuracy: 0.96875
# batch: 42 Accuracy: 0.9375
# batch: 43 Accuracy: 1.0
# batch: 44 Accuracy: 0.96875
# batch: 45 Accuracy: 0.96875
# batch: 46 Accuracy: 1.0
# batch: 47 Accuracy: 1.0
# batch: 48 Accuracy: 0.96875
# batch: 49 Accuracy: 0.9375
# batch: 50 Accuracy: 1.0
# batch: 51 Accuracy: 0.96875
# batch: 52 Accuracy: 0.96875
# batch: 53 Accuracy: 1.0
# batch: 54 Accuracy: 0.96875
# batch: 55 Accuracy: 1.0
# overall accuracy: 0.9826489300173511

# %%
google_test(model)
# Out:
# fatal: destination path 'deep-learning-flower-identifier' already exists and is not an empty directory.
# Requirement already satisfied: airtable in /data/anaconda/envs/py35/lib/python3.5/site-packages (0.3.1)
# Requirement already satisfied: requests>=2.5.3 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from airtable) (2.18.4)
# Requirement already satisfied: certifi>=2017.4.17 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from requests>=2.5.3->airtable) (2018.8.24)
# Requirement already satisfied: idna<2.7,>=2.5 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from requests>=2.5.3->airtable) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from requests>=2.5.3->airtable) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from requests>=2.5.3->airtable) (1.22)
# 5.3.0
# Batch accuracy (Size 32): 0.9375
# Batch accuracy (Size 32): 0.96875
# Batch accuracy (Size 32): 0.9375
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 0.96875
# Batch accuracy (Size 32): 0.96875
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 0.96875
# Batch accuracy (Size 32): 0.96875
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 0.96875
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 0.96875
# Batch accuracy (Size 32): 0.9375
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 0.9375
# Batch accuracy (Size 32): 0.96875
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 0.96875
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 0.96875
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 0.9375
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 0.9375
# Batch accuracy (Size 32): 0.96875
# Batch accuracy (Size 32): 0.9375
# Batch accuracy (Size 32): 1.0
# Mean accuracy: 0.9755859375

# %%
best_acc = 0.9826
model.load_state_dict(torch.load('goog.pt'))
for idx,param in enumerate(model.parameters()):
    if idx > 15:
        param.requires_grad = True

epochs = 20
lr = 1e-5
gamma = 0.1
step_size = 5
momentum = 0.8
cooldown = 1


optimizer = optim.Adam(model.parameters(), lr=lr)
criterion = nn.CrossEntropyLoss()
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, patience=step_size, cooldown=cooldown, verbose=True)

# %%
best_acc, model = train(epochs, model, optimizer, scheduler, dataloaders, criterion, model_name="goog.pt", best_acc=best_acc)
# Out:
# Epoch 1/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0966 Acc: 0.9731
# valid.......................................................
# valid Loss: 0.0095 Acc: 0.9971
# accuracy increased from 0.9826 to 0.9971, saving model....
#
# Epoch 2/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0999 Acc: 0.9737
# valid.......................................................
# valid Loss: 0.0115 Acc: 0.9977
# accuracy increased from 0.9971 to 0.9977, saving model....
#
# Epoch 3/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.1116 Acc: 0.9697
# valid.......................................................
# valid Loss: 0.0113 Acc: 0.9977
# accuracy increased from 0.9977 to 0.9977, saving model....
#
# Epoch 4/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.1111 Acc: 0.9684
# valid.......................................................
# valid Loss: 0.0140 Acc: 0.9965
#
# Epoch 5/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0971 Acc: 0.9728
# valid.......................................................
# valid Loss: 0.0152 Acc: 0.9960
#
# Epoch 6/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0955 Acc: 0.9725
# valid.......................................................
# valid Loss: 0.0174 Acc: 0.9931
#
# Epoch 7/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0833 Acc: 0.9780
# valid.......................................................
# Epoch     6: reducing learning rate of group 0 to 1.0000e-06.
# valid Loss: 0.0132 Acc: 0.9960
#
# Epoch 8/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0980 Acc: 0.9748
# valid.......................................................
# valid Loss: 0.0113 Acc: 0.9960
#
# Epoch 9/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0862 Acc: 0.9763
# valid.......................................................
# valid Loss: 0.0120 Acc: 0.9960
#
# Epoch 10/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0925 Acc: 0.9747
# valid.......................................................
# valid Loss: 0.0092 Acc: 0.9965
#
# Epoch 11/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0879 Acc: 0.9758
# valid.......................................................
# valid Loss: 0.0098 Acc: 0.9960
#
# Epoch 12/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0779 Acc: 0.9785
# valid.......................................................
# valid Loss: 0.0097 Acc: 0.9965
#
# Epoch 13/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0775 Acc: 0.9779
# valid.......................................................
# valid Loss: 0.0094 Acc: 0.9971
#
# Epoch 14/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0805 Acc: 0.9783
# valid.......................................................
# valid Loss: 0.0098 Acc: 0.9965
#
# Epoch 15/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0816 Acc: 0.9774
# valid.......................................................
# valid Loss: 0.0091 Acc: 0.9971
#
# Epoch 16/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0790 Acc: 0.9775
# valid.......................................................
# valid Loss: 0.0100 Acc: 0.9965
#
# Epoch 17/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0831 Acc: 0.9768
# valid.......................................................
# valid Loss: 0.0093 Acc: 0.9977
# accuracy increased from 0.9977 to 0.9977, saving model....
#
# Epoch 18/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0821 Acc: 0.9779
# valid.......................................................
# valid Loss: 0.0094 Acc: 0.9965
#
# Epoch 19/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0744 Acc: 0.9809
# valid.......................................................
# valid Loss: 0.0096 Acc: 0.9977
# accuracy increased from 0.9977 to 0.9977, saving model....
#
# Epoch 20/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0843 Acc: 0.9766
# valid.......................................................
# valid Loss: 0.0088 Acc: 0.9971
#
# Training complete in 256m 40s
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="https://sound.peal.io/ps/audios/000/000/537/original/woo_vu_luvub_dub_dub.wav" type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
test(model, dataloaders)
# Out:
# batch: 1 Accuracy: 1.0
# batch: 2 Accuracy: 1.0
# batch: 3 Accuracy: 1.0
# batch: 4 Accuracy: 1.0
# batch: 5 Accuracy: 0.96875
# batch: 6 Accuracy: 1.0
# batch: 7 Accuracy: 1.0
# batch: 8 Accuracy: 1.0
# batch: 9 Accuracy: 1.0
# batch: 10 Accuracy: 1.0
# batch: 11 Accuracy: 1.0
# batch: 12 Accuracy: 1.0
# batch: 13 Accuracy: 1.0
# batch: 14 Accuracy: 0.96875
# batch: 15 Accuracy: 1.0
# batch: 16 Accuracy: 1.0
# batch: 17 Accuracy: 1.0
# batch: 18 Accuracy: 1.0
# batch: 19 Accuracy: 1.0
# batch: 20 Accuracy: 1.0
# batch: 21 Accuracy: 1.0
# batch: 22 Accuracy: 1.0
# batch: 23 Accuracy: 1.0
# batch: 24 Accuracy: 1.0
# batch: 25 Accuracy: 1.0
# batch: 26 Accuracy: 1.0
# batch: 27 Accuracy: 1.0
# batch: 28 Accuracy: 1.0
# batch: 29 Accuracy: 1.0
# batch: 30 Accuracy: 1.0
# batch: 31 Accuracy: 1.0
# batch: 32 Accuracy: 1.0
# batch: 33 Accuracy: 1.0
# batch: 34 Accuracy: 1.0
# batch: 35 Accuracy: 1.0
# batch: 36 Accuracy: 0.96875
# batch: 37 Accuracy: 1.0
# batch: 38 Accuracy: 1.0
# batch: 39 Accuracy: 0.96875
# batch: 40 Accuracy: 1.0
# batch: 41 Accuracy: 1.0
# batch: 42 Accuracy: 1.0
# batch: 43 Accuracy: 1.0
# batch: 44 Accuracy: 1.0
# batch: 45 Accuracy: 1.0
# batch: 46 Accuracy: 1.0
# batch: 47 Accuracy: 1.0
# batch: 48 Accuracy: 1.0
# batch: 49 Accuracy: 1.0
# batch: 50 Accuracy: 1.0
# batch: 51 Accuracy: 1.0
# batch: 52 Accuracy: 1.0
# batch: 53 Accuracy: 1.0
# batch: 54 Accuracy: 1.0
# batch: 55 Accuracy: 1.0
# overall accuracy: 0.9976865240023135

# %%
google_test(model)
# Out:
# fatal: destination path 'deep-learning-flower-identifier' already exists and is not an empty directory.
# Requirement already satisfied: airtable in /data/anaconda/envs/py35/lib/python3.5/site-packages (0.3.1)
# Requirement already satisfied: requests>=2.5.3 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from airtable) (2.18.4)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from requests>=2.5.3->airtable) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from requests>=2.5.3->airtable) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from requests>=2.5.3->airtable) (2018.8.24)
# Requirement already satisfied: idna<2.7,>=2.5 in /data/anaconda/envs/py35/lib/python3.5/site-packages (from requests>=2.5.3->airtable) (2.6)
# 5.3.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 0.96875
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 0.96875
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 0.96875
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 0.96875
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 1.0
# Batch accuracy (Size 32): 0.96875
# Batch accuracy (Size 32): 1.0
# Mean accuracy: 0.9951171875

# %%
best_acc = 0.9977
model.load_state_dict(torch.load('goog.pt'))

for idx,param in enumerate(model.parameters()):
    param.requires_grad = True

epochs = 20
lr = 1e-12
gamma = 0.1
step_size = 5
momentum = 0.8
cooldown = 1

model.to(device)
optimizer = optim.Adam(model.parameters(), lr=lr)
criterion = nn.CrossEntropyLoss()
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, patience=step_size, cooldown=cooldown, verbose=True)

# %%
best_acc,model = train(epochs, model, optimizer, scheduler, dataloaders, criterion, model_name="goog_final.pt",best_acc=best_acc)
# Out:
# Epoch 1/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0750 Acc: 0.9805
# valid.......................................................
# valid Loss: 0.0091 Acc: 0.9971
#
# Epoch 2/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0743 Acc: 0.9792
# valid.......................................................
# valid Loss: 0.0098 Acc: 0.9971
#
# Epoch 3/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0782 Acc: 0.9773
# valid.......................................................
# valid Loss: 0.0090 Acc: 0.9965
#
# Epoch 4/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0819 Acc: 0.9771
# valid.......................................................
# valid Loss: 0.0090 Acc: 0.9971
#
# Epoch 5/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0796 Acc: 0.9785
# valid.......................................................
# valid Loss: 0.0094 Acc: 0.9965
#
# Epoch 6/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0816 Acc: 0.9770
# valid.......................................................
# valid Loss: 0.0086 Acc: 0.9977
#
# Epoch 7/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0716 Acc: 0.9807
# valid.......................................................
# valid Loss: 0.0099 Acc: 0.9971
#
# Epoch 8/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0675 Acc: 0.9830
# valid.......................................................
# valid Loss: 0.0096 Acc: 0.9971
#
# Epoch 9/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0796 Acc: 0.9779
# valid.......................................................
# valid Loss: 0.0100 Acc: 0.9971
#
# Epoch 10/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0828 Acc: 0.9766
# valid.......................................................
# valid Loss: 0.0093 Acc: 0.9971
#
# Epoch 11/20
# ----------
# train............................................................................................................................................................................................................................................................................................
# train Loss: 0.0776 Acc: 0.9775
# valid.......................................................
# valid Loss: 0.0095 Acc: 0.9971
#
# Epoch 12/20
# ----------
# train.........................................................................................................................................................................................................

# %%
test(model, dataloaders)

# %%
google_test(model)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-1a8368f8e67b> in <module>()
# ----> 1 model.device()
#
# /data/anaconda/envs/py35/lib/python3.5/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     533                 return modules[name]
#     534         raise AttributeError("'{}' object has no attribute '{}'".format(
# --> 535             type(self).__name__, name))
#     536
#     537     def __setattr__(self, name, value):
#
# AttributeError: 'ResNet' object has no attribute 'device'

# %%
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="https://sound.peal.io/ps/audios/000/000/537/original/woo_vu_luvub_dub_dub.wav" type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
